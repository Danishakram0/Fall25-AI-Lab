# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Data Gathering
# Data Loading

# %%
df = pd.read_csv("diabetes.csv")

# %% [markdown]
# Data Exploration

# %%
df.head(2)
# Out:
#    Glucose  BloodPressure  Insulin  DiabetesPedigreeFunction  Outcome  \
# 0       86             22        0                     0.627        1
# 1       23             19        0                     0.351        0
#
#    Diabetes
# 0         1
# 1         0

# %%
df.tail(2)
# Out:
#      Glucose  BloodPressure  Insulin  DiabetesPedigreeFunction  Outcome  \
# 766       64             14        0                     0.349        1
# 767       31             21        0                     0.315        0
#
#      Diabetes
# 766         1
# 767         0

# %%
df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'Insulin', 'DiabetesPedigreeFunction',
#        'Outcome', 'Diabetes'],
#       dtype='object')

# %%
df.count()
# Out:
# Glucose                     768
# BloodPressure               768
# Insulin                     768
# DiabetesPedigreeFunction    768
# Outcome                     768
# Diabetes                    768
# dtype: int64

# %%
df.describe()
# Out:
#           Glucose  BloodPressure     Insulin  DiabetesPedigreeFunction  \
# count  768.000000     768.000000  768.000000                768.000000
# mean    59.322917      21.264323   42.417969                  0.471876
# std     30.510176       8.688687   52.689353                  0.331329
# min      0.000000       0.000000    0.000000                  0.078000
# 25%     37.000000      16.000000    0.000000                  0.243750
# 50%     55.000000      22.000000    8.500000                  0.372500
# 75%     78.250000      27.000000   80.250000                  0.626250
# max    135.000000      46.000000  185.000000                  2.420000
#
#           Outcome    Diabetes
# count  768.000000  768.000000
# mean     0.348958    0.348958
# std      0.476951    0.476951
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   768 non-null    int64
#  1   BloodPressure             768 non-null    int64
#  2   Insulin                   768 non-null    int64
#  3   DiabetesPedigreeFunction  768 non-null    float64
#  4   Outcome                   768 non-null    int64
#  5   Diabetes                  768 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 36.1 KB

# %%
df.shape
print(f"Number of Rows: {df.shape[0]} and Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 768 and Number of Columns: 6

# %%
# df['BMI'].unique()

# %%
df.nunique()
# Out:
# Glucose                     136
# BloodPressure                47
# Insulin                     186
# DiabetesPedigreeFunction    517
# Outcome                       2
# Diabetes                      2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Glucose                     0
# BloodPressure               0
# Insulin                     0
# DiabetesPedigreeFunction    0
# Outcome                     0
# Diabetes                    0
# dtype: int64

# %% [markdown]
# Data Pre-Processing

# %% [markdown]
# Manage Null Values

# %%
df = df.drop('Age', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = df.drop('Age', axis=1)
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Age'] not found in axis"

# %%
df = df.drop('BMI', axis=1)

# %%
def fillnaObjectMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns =[ 'Glucose', 'BloodPressure', 'Insulin', 'DiabetesPedigreeFunction', 'Outcome']
fillnaObjectMode(columns)

# %%
def fillnaIntMode(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mode()[0])

columns =[ 'Glucose', 'BloodPressure', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
fillnaIntMode(columns)

# %%
def fillnaFloatMean(cols):
    for i in cols:
        df[i] = df[i].fillna(df[i].mean())


columns =[ 'Glucose', 'BloodPressure', 'Insulin', 'DiabetesPedigreeFunction', 'Outcome']
fillnaFloatMean(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   768 non-null    int64
#  1   BloodPressure             768 non-null    int64
#  2   Insulin                   768 non-null    int64
#  3   DiabetesPedigreeFunction  768 non-null    float64
#  4   Outcome                   768 non-null    int64
#  5   Diabetes                  768 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 36.1 KB

# %% [markdown]
# Manage Data Types

# %%
df['Diabetes'] = df['Outcome'].astype('int64')

# %%
def changeFloatToInt(cols):
    for i in cols:
        df[i] = df[i].astype('int64')

columns = [ 'Outcome', 'Glucose', 'BloodPressure', 'Insulin',]
changeFloatToInt(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   768 non-null    int64
#  1   BloodPressure             768 non-null    int64
#  2   Insulin                   768 non-null    int64
#  3   DiabetesPedigreeFunction  768 non-null    float64
#  4   Outcome                   768 non-null    int64
#  5   Diabetes                  768 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 36.1 KB

# %%
def convertObjToInt(cols):
    for i in cols:
        data = pd.DataFrame({i:df[i].unique()})
        data_LE = LabelEncoder()
        data_LE.fit(np.ravel(data))   
        df[i] = data_LE.transform(df[i])
        

columns = [ 'Outcome', 'Glucose', 'BloodPressure', 'Insulin',]
convertObjToInt(columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Glucose                   768 non-null    int64
#  1   BloodPressure             768 non-null    int64
#  2   Insulin                   768 non-null    int64
#  3   DiabetesPedigreeFunction  768 non-null    float64
#  4   Outcome                   768 non-null    int64
#  5   Diabetes                  768 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 36.1 KB

# %%
df.head(2)
# Out:
#    Glucose  BloodPressure  Insulin  DiabetesPedigreeFunction  Outcome  \
# 0       86             22        0                     0.627        1
# 1       23             19        0                     0.351        0
#
#    Diabetes
# 0         1
# 1         0

# %%
df.to_csv('diabetes.csv', index=False, header=True)

# %%
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Glucose  BloodPressure  Insulin  DiabetesPedigreeFunction  Outcome  \
# 0         86             22        0                     0.627        1
# 1         23             19        0                     0.351        0
# 2        121             17        0                     0.672        1
# 3         27             19       62                     0.167        0
# 4         75              4      102                     2.288        1
# ..       ...            ...      ...                       ...      ...
# 763       39             25      108                     0.171        0
# 764       60             21        0                     0.340        0
# 765       59             22       71                     0.245        0
# 766       64             14        0                     0.349        1
# 767       31             21        0                     0.315        0
#
#      Diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# 4           1
# ..        ...
# 763         0
# 764         0
# 765         0
# 766         1
# 767         0
#
# [768 rows x 6 columns]

# %% [markdown]
# Train - Test Splitting

# %%
import pandas as pd
df = pd.read_csv('diabetes.csv')

df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'Insulin', 'DiabetesPedigreeFunction',
#        'Outcome', 'Diabetes'],
#       dtype='object')

# %%
X = df.drop('Outcome', axis=1)   
y = df['Glucose']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X,y, test_size=0.3, shuffle=False)

# %%
print(train_X.shape, train_y.shape)
print(test_X.shape, test_y.shape)
# Out:
# (537, 5) (537,)
# (231, 5) (231,)

# %% [markdown]
# Applying Classifier / Model Training

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df = pd.read_csv("diabetes.csv")

# %%
def convertObjToInt(cols):
    for i in cols:
        label = LabelEncoder()
        df[i] = label.fit_transform(df[i])
        
columns = [ 'Outcome', 'Glucose', 'BloodPressure', 'Insulin',]
convertObjToInt(columns)

# %%
X = df.drop("Diabetes", axis=1)
y = df["Diabetes"]

# %%
train_X, test_X, train_y, test_y = train_test_split(
    X, y, test_size=0.3, shuffle=True, random_state=42
)

# %%
model_svc = SVC()

model_svc.fit(train_X, train_y)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
accuracy = model_svc.score(test_X, test_y)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7316017316017316

# %%
import pickle
pickle.dump(model_svc, open('model_svc.pkl', 'wb'))

# %%
import pickle
model_svc = pickle.load(open('model_svc.pkl', 'rb'))
